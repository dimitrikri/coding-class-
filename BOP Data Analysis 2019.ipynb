# %%
# %matplotlib notebook 
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import seaborn as sns
sns.set()

# %%
data2018 = pd.read_csv('C:/Users/oyster1_tmp/Desktop/STEM-2019/STEM-2019/2018expeditions.csv', header=0)

# %%
# look at the first five rows
data2018.head()
# Out:
#                                           Unnamed: 0  \
# 0  Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                 Oil sheen present?\r\n(1=Yes,0=No)
# 2                           Oyster Measurements (mm)
# 3                                 Substrate Shell #1
# 4                                   Outer side photo
#
#   October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016  \
# 0                                                  3
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016  \
# 0                                                  4
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017  \
# 0                                                 2
# 1                                                 0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017  \
# 0                                                4
# 1                                                0
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#   TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#   Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Test\r\nBOP Pier 101,\r\nSeptember 12, 2017  \
# 0                                         NaN
# 1                                           0
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017  \
# 0                                              4
# 1                                              1
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   test 3\r\nPier 101,\r\nDecember 7, 2017  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017  \
# 0                                            1
# 1                                            0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018
# 0                                           3.0
# 1                                           0.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 22 columns]

# %%
# Display the column names
data2018.columns
# Out:
# Index(['Unnamed: 0',
#        'October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016',
#        'ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016',
#        'TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016',
#        'TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016',
#        'Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016',
#        '789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016',
#        'Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017',
#        'Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017',
#        'TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017',
#        'TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\r\nApril 20, 2017',
#        'Sherman Creek 3\r\nSherman Creek South,\r\nApril 21, 2017',
#        'TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017',
#        'Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017',
#        'Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017',
#        'Test\r\nBOP Pier 101,\r\nSeptember 12, 2017',
#        'Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017',
#        'No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017',
#        'test 3\r\nPier 101,\r\nDecember 7, 2017',
#        'Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017',
#        'Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017',
#        'SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018'],
#       dtype='object')

# %%
# look at the last five rows
data2018.tail()
# Out:
#     Unnamed: 0 October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016  \
# 220      Label                                                NaN
# 221     Method                                                NaN
# 222       Unit                                                NaN
# 223    Results                                                NaN
# 224    Average                                                NaN
#
#     ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017  \
# 220                                               NaN
# 221                                               NaN
# 222                                               NaN
# 223                                               NaN
# 224                                               NaN
#
#     Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017  \
# 220                                              NaN
# 221                                              NaN
# 222                                              NaN
# 223                                              NaN
# 224                                              NaN
#
#     TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017  \
# 220                                          Phosphate
# 221                                        test strips
# 222                                                ppm
# 223                                              5,5,5
# 224                                                  5
#
#                          ...                       \
# 220                      ...
# 221                      ...
# 222                      ...
# 223                      ...
# 224                      ...
#
#     TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Test\r\nBOP Pier 101,\r\nSeptember 12, 2017  \
# 220                                         NaN
# 221                                         NaN
# 222                                         NaN
# 223                                         NaN
# 224                                         NaN
#
#     Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017  \
# 220                                            NaN
# 221                                            NaN
# 222                                            NaN
# 223                                            NaN
# 224                                            NaN
#
#     No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     test 3\r\nPier 101,\r\nDecember 7, 2017  \
# 220                                     NaN
# 221                                     NaN
# 222                                     NaN
# 223                                     NaN
# 224                                     NaN
#
#     Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017  \
# 220                                          NaN
# 221                                          NaN
# 222                                          NaN
# 223                                          NaN
# 224                                          NaN
#
#     Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018
# 220                                           NaN
# 221                                           NaN
# 222                                           NaN
# 223                                           NaN
# 224                                           NaN
#
# [5 rows x 22 columns]

# %%
# transpose the data -- interchange rows and columns
data2018.T
# Out:
#                                                                                                   0    \
# Unnamed: 0                                          Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                  3
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                  4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                  4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                  6
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                  6
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                  2
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                   2
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                    4
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                                                  5
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                                  3
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                                  3
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                                                  4
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                  2
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                                  5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                      4
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                        1
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                       3
#
#                                                                                    1    \
# Unnamed: 0                                          Oil sheen present?\r\n(1=Yes,0=No)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                   0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                   1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                   0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                   0
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                   0
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                   0
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                    0
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                     0
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                                   0
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                   0
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                   0
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                                   1
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                   0
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                   0
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                          0
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                       1
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                 NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                            NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                         0
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                 NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                        0
#
#                                                                          2    \
# Unnamed: 0                                          Oyster Measurements (mm)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                       NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                       NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                       NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                       NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                        NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                         NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                       NaN
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                       NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                       NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                       NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                       NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                       NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                              NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                           NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                       NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                  NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                             NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                       NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                            NaN
#
#                                                                    3    \
# Unnamed: 0                                          Substrate Shell #1
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                 NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                 NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                 NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                 NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                  NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                   NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                 NaN
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                 NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                 NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                 NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                 NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                 NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                        NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                     NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                 NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                            NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                       NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                 NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                      NaN
#
#                                                                                                   4    \
# Unnamed: 0                                                                           Outer side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  http://s3-us-west-1.amazonaws.com/digital-plat...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                                NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                                NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  http://s3-us-west-1.amazonaws.com/digital-plat...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                                NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
#                                                                                                   5    \
# Unnamed: 0                                                                           Inner side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  http://s3-us-west-1.amazonaws.com/digital-plat...
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  http://s3-us-west-1.amazonaws.com/digital-plat...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                                NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                                NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  http://s3-us-west-1.amazonaws.com/digital-plat...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                                NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
#                                                           6    \
# Unnamed: 0                                           Set date
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  7/14/2015
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  11/9/2016
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  11/9/2016
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...  7/14/2015
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017   7/14/2015
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017    7/14/2015
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  7/31/2015
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  7/31/2015
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  11/9/2016
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  7/31/2015
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  7/14/2015
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  11/9/2016
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017         8/12/2016
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017      7/14/2015
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...  5/10/2018
# test 3\r\nPier 101,\r\nDecember 7, 2017             7/14/2015
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017        7/14/2015
# Test for Maintenance\r\nBOP Test Station,\r\nDe...        NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018             NaN
#
#                                                                      7    \
# Unnamed: 0                                                        Source
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  Muscongus Bay, Maine
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          Harlem River
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# Sherman Creek Park 2\r\nSherman Creek South,\r\...          Harlem River
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...  Muscongus Bay, Maine
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017   Muscongus Bay, Maine
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017    Muscongus Bay, Maine
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  Muscongus Bay, Maine
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  Muscongus Bay, Maine
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...          Harlem River
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  Muscongus Bay, Maine
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  Muscongus Bay, Maine
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...          Harlem River
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                           EB
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017      Muscongus Bay, Maine
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...   Soundview, New York
# test 3\r\nPier 101,\r\nDecember 7, 2017             Muscongus Bay, Maine
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017        Muscongus Bay, Maine
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                   NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                        NaN
#
#                                                                                          8    \
# Unnamed: 0                                          Total number of live oysters at baseline
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                         0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                        12
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         4
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                        12
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                         0
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                          0
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                           0
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                                         4
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                         4
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                        12
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                                         4
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                         0
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                        12
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                5
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                             0
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                         6
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                    0
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                               0
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                       NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                            NaN
#
#                                                                                            9    \
# Unnamed: 0                                          Total mass of live oysters at baseline (g)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                           0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                           2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                           2
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                           0
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                            0
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                             0
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                                         3.8
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                         3.8
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                                           2
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                                         3.8
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                           0
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                                           2
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                 64
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                               0
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                          67
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                      0
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                 0
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                         NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                              NaN
#
#                                                      ...             215  \
# Unnamed: 0                                           ...          Method
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   ...             NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   ...             NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   ...             NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   ...             NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   ...             NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...   ...             NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017    ...             NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017     ...             NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...   ...     Test strips
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...   ...             NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...   ...             NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...   ...             NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017   ...             NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...   ...             NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017          ...             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017       ...             NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...   ...             NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017              ...             NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017         ...             NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...   ...             NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018        ...             NaN
#
#                                                      216      217      218  \
# Unnamed: 0                                          Unit  Results  Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   NaN      NaN      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   NaN      NaN      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   NaN      NaN      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   NaN      NaN      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   NaN      NaN      NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...   NaN      NaN      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017    NaN      NaN      NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017     NaN      NaN      NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...   ppm    0,0,0        0
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...   NaN      NaN      NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...   NaN      NaN      NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...   NaN      NaN      NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017   NaN      NaN      NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...   NaN      NaN      NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017          NaN      NaN      NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017       NaN      NaN      NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...   NaN      NaN      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017              NaN      NaN      NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017         NaN      NaN      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...   NaN      NaN      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018        NaN      NaN      NaN
#
#                                                       219        220  \
# Unnamed: 0                                          Other      Label
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...    NaN        NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...    NaN        NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...    NaN        NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...    NaN        NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...    NaN        NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...    NaN        NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017     NaN        NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017      NaN        NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...    NaN  Phosphate
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...    NaN        NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...    NaN        NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...    NaN        NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017    NaN        NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    NaN        NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017           NaN        NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017        NaN        NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...    NaN        NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017               NaN        NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017          NaN        NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...    NaN        NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018         NaN        NaN
#
#                                                             221   222  \
# Unnamed: 0                                               Method  Unit
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...          NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...          NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...          NaN   NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...          NaN   NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...          NaN   NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017           NaN   NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017            NaN   NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  test strips   ppm
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...          NaN   NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...          NaN   NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...          NaN   NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017          NaN   NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...          NaN   NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                 NaN   NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017              NaN   NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...          NaN   NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                     NaN   NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                NaN   NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...          NaN   NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018               NaN   NaN
#
#                                                         223      224
# Unnamed: 0                                          Results  Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...      NaN      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...      NaN      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...      NaN      NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...      NaN      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017       NaN      NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017        NaN      NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...    5,5,5        5
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...      NaN      NaN
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...      NaN      NaN
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...      NaN      NaN
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017      NaN      NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...      NaN      NaN
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017             NaN      NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017          NaN      NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...      NaN      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                 NaN      NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017            NaN      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...      NaN      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018           NaN      NaN
#
# [22 rows x 225 columns]

# %%
data2018.head()
# Out:
#                                           Unnamed: 0  \
# 0  Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                 Oil sheen present?\r\n(1=Yes,0=No)
# 2                           Oyster Measurements (mm)
# 3                                 Substrate Shell #1
# 4                                   Outer side photo
#
#   October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016  \
# 0                                                  3
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016  \
# 0                                                  4
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017  \
# 0                                                 2
# 1                                                 0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017  \
# 0                                                4
# 1                                                0
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#   TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#   Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Test\r\nBOP Pier 101,\r\nSeptember 12, 2017  \
# 0                                         NaN
# 1                                           0
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017  \
# 0                                              4
# 1                                              1
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   test 3\r\nPier 101,\r\nDecember 7, 2017  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017  \
# 0                                            1
# 1                                            0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018
# 0                                           3.0
# 1                                           0.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 22 columns]

# %%
data2018.iloc[0]
# Out:
# 0      Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                     Oil sheen present?\r\n(1=Yes,0=No)
# 2                               Oyster Measurements (mm)
# 3                                     Substrate Shell #1
# 4                                       Outer side photo
# 5                                       Inner side photo
# 6                                               Set date
# 7                                                 Source
# 8               Total number of live oysters at baseline
# 9             Total mass of live oysters at baseline (g)
# 10                 Total number of live oysters on shell
# 11     Total mass of scrubbed substrate shell + oyste...
# 12                                     Measurements (mm)
# 13                     Minimum size of live oysters (mm)
# 14                     Maximum size of live oysters (mm)
# 15                     Average size of live oysters (mm)
# 16                                    Substrate Shell #2
# 17                                      Outer side photo
# 18                                      Inner side photo
# 19                                              Set date
# 20                                                Source
# 21              Total number of live oysters at baseline
# 22            Total mass of live oysters at baseline (g)
# 23                 Total number of live oysters on shell
# 24     Total mass of scrubbed substrate shell + oyste...
# 25                                     Measurements (mm)
# 26                     Minimum size of live oysters (mm)
# 27                     Maximum size of live oysters (mm)
# 28                     Average size of live oysters (mm)
# 29                                    Substrate Shell #3
#                              ...
# 195                                               Method
# 196                                                 Unit
# 197                                              Results
# 198                                              Average
# 199                                                   pH
# 200                                               Method
# 201                                                 Unit
# 202                                              Results
# 203                                              Average
# 204                                            Turbidity
# 205                                               Method
# 206                                                 Unit
# 207                                              Results
# 208                                              Average
# 209                                              Ammonia
# 210                                               Method
# 211                                                 Unit
# 212                                              Results
# 213                                              Average
# 214                                             Nitrates
# 215                                               Method
# 216                                                 Unit
# 217                                              Results
# 218                                              Average
# 219                                                Other
# 220                                                Label
# 221                                               Method
# 222                                                 Unit
# 223                                              Results
# 224                                              Average
# Name: Unnamed: 0, Length: 225, dtype: object

# %%
# change the column names to the names in the first row  instead of 1, 2, ... 
data2018.columns = data2018.iloc[0]

# %%
data2018.head()
# Out:
# 0 Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)  \
# 0  Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                 Oil sheen present?\r\n(1=Yes,0=No)
# 2                           Oyster Measurements (mm)
# 3                                 Substrate Shell #1
# 4                                   Outer side photo
#
# 0    3    4    4    6    6    2    2    4  \
# 0    3    4    4    6    6    2    2    4
# 1    0    1    0    0    0    0    0    0
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# 0                                                  5 ...   \
# 0                                                  5 ...
# 1                                                  0 ...
# 2                                                NaN ...
# 3                                                NaN ...
# 4  http://s3-us-west-1.amazonaws.com/digital-plat... ...
#
# 0                                                  4    2    5  NaN    4  NaN  \
# 0                                                  4    2    5  NaN    4  NaN
# 1                                                  1    0    0    0    1  NaN
# 2                                                NaN  NaN  NaN  NaN  NaN  NaN
# 3                                                NaN  NaN  NaN  NaN  NaN  NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...  NaN  NaN  NaN  NaN  NaN
#
# 0  NaN    1 NaN  3.0
# 0  NaN    1 NaN  3.0
# 1  NaN    0 NaN  0.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  NaN NaN  NaN
# 4  NaN  NaN NaN  NaN
#
# [5 rows x 22 columns]

# %%
# since the first row of the transposed data contains the variable names and not data, drop the first row
data2018 = data2018.drop(data2018.index[0])

# %%
# take a look and make sure you got what you wanted
data2018.head()
# Out:
# Unnamed: 0                                         Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                  3
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                  4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                  4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                  6
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                  6
#
# Unnamed: 0                                         Oil sheen present?\r\n(1=Yes,0=No)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                  0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                  1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                  0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                  0
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                  0
#
# Unnamed: 0                                         Oyster Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                      NaN
#
# Unnamed: 0                                         Substrate Shell #1  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                NaN
#
# Unnamed: 0                                         Outer side photo  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...              NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...              NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...              NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...              NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...              NaN
#
# Unnamed: 0                                                                           Inner side photo  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  http://s3-us-west-1.amazonaws.com/digital-plat...
#
# Unnamed: 0                                           Set date  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  7/14/2015
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  11/9/2016
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  11/9/2016
#
# Unnamed: 0                                                        Source  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  Muscongus Bay, Maine
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          Harlem River
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# Sherman Creek Park 2\r\nSherman Creek South,\r\...          Harlem River
#
# Unnamed: 0                                         Total number of live oysters at baseline  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                        0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                       12
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                        4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                        4
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                       12
#
# Unnamed: 0                                         Total mass of live oysters at baseline (g)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                          0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                          2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                        3.8
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                        3.8
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                          2
#
# Unnamed: 0                                           ...   Method Unit  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   ...      NaN  NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   ...      NaN  NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   ...      NaN  NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   ...      NaN  NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   ...      NaN  NaN
#
# Unnamed: 0                                         Results Average Other  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...     NaN     NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...     NaN     NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...     NaN     NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...     NaN     NaN   NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...     NaN     NaN   NaN
#
# Unnamed: 0                                         Label Method Unit Results  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   NaN    NaN  NaN     NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   NaN    NaN  NaN     NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   NaN    NaN  NaN     NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   NaN    NaN  NaN     NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   NaN    NaN  NaN     NaN
#
# Unnamed: 0                                         Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...     NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...     NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...     NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...     NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...     NaN
#
# [5 rows x 225 columns]

# %%
data2018.shape
# Out:
# (21, 225)

# %%
# you can print all the variable names
for i in range(len(data2018.columns)):
    print(data2018.columns[i])
# Out:
# Water color
# (1=Light Blue,2=Dark Blue,3=Light Green,
# 4=Dark Green,5=Light Brown,6=Dark Brown)
# Oil sheen present?
# (1=Yes,0=No)
# Oyster Measurements (mm)
# Substrate Shell #1
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #2
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #3
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #4
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #5
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #6
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #7
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #8
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #9
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #10
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Minimum size of all live oysters (mm)
# Maximum size of all live oysters (mm)
# Average size of all live oysters (mm)
# Total number of all live oysters
# Water Quality Sample #1
# Depth (m)
# Location (coordinates)
# Water Temperature
# Method
# Unit
# Results
# Average
# Dissolved Oxygen
# Method
# Unit
# Results
# Average
# Salinity
# Method
# Unit
# Results
# Average
# pH
# Method
# Unit
# Results
# Average
# Turbidity
# Method
# Unit
# Results
# Average
# Ammonia
# Method
# Unit
# Results
# Average
# Nitrates
# Method
# Unit
# Results
# Average
# Other
# Label
# Method
# Unit
# Results
# Average
# Water Quality Sample #2
# Depth (m)
# Location (coordinates)
# Water Temperature
# Method
# Unit
# Results
# Average
# Dissolved Oxygen
# Method
# Unit
# Results
# Average
# Salinity
# Method
# Unit
# Results
# Average
# pH
# Method
# Unit
# Results
# Average
# Turbidity
# Method
# Unit
# Results
# Average
# Ammonia
# Method
# Unit
# Results
# Average
# Nitrates
# Method
# Unit
# Results
# Average
# Other
# Label
# Method
# Unit
# Results
# Average

# %%
# you can explore specific subsets of the data
# "Oil sheen present? (1=Yes,0=No)" is the second column so we can extract it via implicit indexing
# Remember  Python indexing is zero based
for i in range(3):
    print(data2018.iloc[i, 1])
# Out:
# 0
# 1
# 0

# %%
# Display the measuremts for all substrates for the second expedition
data2018.iloc[0]["Measurements (mm)"]
# Out:
# Measurements (mm)    80,5.9
# Measurements (mm)       NaN
# Measurements (mm)        56
# Measurements (mm)        64
# Measurements (mm)       NaN
# Measurements (mm)       NaN
# Measurements (mm)       6.1
# Measurements (mm)        64
# Measurements (mm)        70
# Measurements (mm)       NaN
# Name: October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016, dtype: object

# %%
# You can select multiple columns by using an array as the index
data2018[["Measurements (mm)", "Total number of all live oysters"]]
# Out:
# Unnamed: 0                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                             80,5.9
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  3.2,6.2,0.3,0.4,2.5,3.4,2,3.2,1.5
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                           20,26,17
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                              70,60
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                  70
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                72,87
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                  42,35,35,45,35,25
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            44,36,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                        6,5.2,4.2,3
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   30,30,50,40,30.5
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                              81,75
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...        4.1,3.5,3.6,4.2,5.5,3.3,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                      5,10
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      8
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                1,2
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         88,75
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                   105,88
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                     NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    1.5,3.4,1.3,2.3,2.2,2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              25,23,22,21
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     86,69
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                        NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                              35,18,32,53
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                        41,34,37,40,25,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5.2,4.5,5.1,3.5,3.5,3.2,5.5,5.1,5.3,4.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                            10,40.5,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                      NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    4,4.6,5.2,5.6,4.8,3.6,3.5,5.1,4.5,2.3
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                         15,6
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 115
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 56
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                          1.3,3.4,1,2.4,1.7,3.7,0.9
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                 70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,20,15,18,15,16,18,25,18,16,18,17,20,18,12,2...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  15.1,10.1,14.6,18.6,16,16,15.4,21.1,21.1,18.6,...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.6,3.3,4.3,3.2,3.5,6.2,5.1,3.6,5,3.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...             10,10,10,20,15,15,20,20,21,25,25,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                              3,2.1,3.1,1.9,3.7,2.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                               7,8.5,12
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                              2.4,3.1,2,1.5,2.7,1.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                              80,70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                               57,83
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                   75
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  28,23,20,20,20,20,15,21,18,8,18,15,17,13,16,20...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  29,16,21,7,9,18,2,25,27,26,8,9,5,16,19,13,20,3...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.7,4.5,4.9,2.8,7,3.2,4.8,4.5,4.5,2.9
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  3,3,4,5,5,10,10,10,10,15,10,10,25,25,25,30,32,...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                 73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              2,3.9,4.4,2.1,3.5,4.2,3.4,3.5,5.6,4.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                              Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                    NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                  3,2.1,3.1,1.9,3.7,2.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                    NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                    NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                      NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                26,20,38,27,30,28,41,40
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                     35
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  6.6,5.3,3.4,3,3.4,4.5,5.2,4.3,5.2,6.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                         35,20,30,45,27
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                    NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    3.6,4.4,2.6,4.3,4.2,4,3.4,3,3.6,2.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                           NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                        NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                    NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                               NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                          NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                    NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                         NaN
#
# Unnamed: 0                                                            Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                  NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...           2,3.12,4.4,2.1,3.5,4.2,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                  NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                75,64
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                    64
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                    NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,15,18,18,21,14,25,28,12,25,30,15
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                 20,25,20,30,15,13,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...    3.3,4.5,6,1.8,0.5,6.9,1,5.8,5.9,4
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...          22,19,15,27,22,4,3,15,15,16
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                   60
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  4.6,4.8,2.6,6,3.3,3.7,4.9,5,2.9,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                         NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                  NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                             NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                        NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                  NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                       NaN
#
# Unnamed: 0                                                                    Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                          6.1
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.7,3.8,2,4,2.13,3.5,1,4.04,2.1,3.9,4.7,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                          NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                           65
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                           NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                          37,68
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                            35,18,42,35,40,36
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                               30,40,30,41,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...            2.4,7.8,2,2.9,4.7,3.5,4.7,6,3,4.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                               25,30,32,35,43
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                           64
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6.5,5.2,3.4,5.7,3.2,4.3,6.6,6.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                 NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                              NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                          NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                     NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                          NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                               NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                       64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          3.2,3.01,4,2.04,1.09,1.07,2,1,1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                      NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                        80
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                         79
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                           58,30,34,28,37
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            60,28,20,25,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                    4.6,7,2.7,3.3,3,3.1,5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                           10,15,25,40,45
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                       73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  5.5,4.5,3.2,3.2,2.6,3.6,3.4,4.3,5.1,5.2
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                          NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                        Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                               70
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.1,1.4,2.2,3.4,1.2,3.2,2.3,3.3
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                               81
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                66
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                 30
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                   35,23,28,53,32
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...    25.3,14.1,46.6,31.6,26.3,26.1
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...      3,3.7,1,2.4,8.6,2,3.5,7,4,6
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   15,20,20,25,40
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                               80
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  6.7,3.8,5.1,3.5,3.9,6.5,2.7,3.4
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                     NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                  NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                              NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                    115
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                              NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                   NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    5.6,4.4,5.6,2.5,3.2,2.4,3.5,2.1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...          23,27,20,18,22,30,35,16,26,32,23,18,18,21
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  14,30,10,21,10,19,18,22,30,26,17,15,10,10,20,1...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5,6.4,1.5,6.1,3.5,2.5,3.4,2.4,6,5.5,1.5,5.3,3....
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  10,10,15,20,20,30,25,25,35,30,35,35,35,40,35,4...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6,4.4,2.9,4.1,3.5,4.2,5.6,6.4,4.1,7.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                         Total number of all live oysters
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                7
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                               78
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                2
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                3
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                7
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                9
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                 8
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                  7
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                              102
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                              101
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                               96
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                              100
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                7
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                               89
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                       2
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                    6
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                              NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                           2
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                      3
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                              NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                     3

# %%
# Extract the values for each substrate shell for one expedition
# Recall the expeditions are the rows so we use .iloc to pass the index location (row number)
# This will create an array of strings, each string contains the measurements
# vals is of type numpy.ndarray, and each element of vals is a str
vals = data2018.iloc[0]["Measurements (mm)"].values

# %%
# what is the dtype for vals
type(vals)
# Out:
# numpy.ndarray

# %%
# what is the dtype for the first element of vals
# We see vals is a list of strings
type(vals[0])
# Out:
# str

# %%
vals # we see a mix of str and nan
# Out:
# array(['80,5.9', nan, '56', '64', nan, nan, '6.1', '64', '70', nan],
#       dtype=object)

# %%
type(vals[0].split(","))
# Out:
# list

# %%
# we can't do analysis yet because this is a list of str 
# We break out the individual values for the first strings but each is still a str
# And we have to deal with nan 
# If we try to split() a nan we get an error
vals[0].split(",")
# Out:
# ['80', '5.9']

# %%
# This throws an error because vals[1] is nan and nan's are floats not str
vals[1].split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-12d7566481b6> in <module>()
#       1 # This throws an error because vals[1] is nan and nan's are floats not str
# ----> 2 vals[1].split(",")
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Pandas Series and DataFrames can use the dropna() method to remove nan's
pd.Series(vals).dropna()

# %%
# And to_numeric() converts strings to floats
pd.to_numeric((pd.Series(vals[0].split(",")))
# Out:
# 0    80.0
# 1     5.9
# dtype: float64

# %%
a = vals[0].split(",")
b = pd.Series(a)
c = pd.to_numeric(b)
print

# %%
for v in range(len(vals)):  # let's walk through the string array 
    if type(vals[v]) == str: # if the type is str then we can split() and make it a float
        print(pd.to_numeric(pd.Series(vals).dropna()[v].split(",")))
        # we can also print the mean for each substrate
        print('Substrate Shell #' + str(v+1) + ": \t The mean is ", 
              '%.3f' % pd.to_numeric(pd.Series(vals).dropna()[v].split(",")).mean(), sep='\t')
# Out:
# [80.   5.9]
# Substrate Shell #1: 	 The mean is 	42.950
# [56]
# Substrate Shell #3: 	 The mean is 	56.000
# [64]
# Substrate Shell #4: 	 The mean is 	64.000
# [6.1]
# Substrate Shell #7: 	 The mean is 	6.100
# [64]
# Substrate Shell #8: 	 The mean is 	64.000
# [70]
# Substrate Shell #9: 	 The mean is 	70.000

# %%
# Save the column name to a simple variable rather than retype this whole thing
wc = 'Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)'

# %%
print(wc)
# Out:
# Water color
# (1=Light Blue,2=Dark Blue,3=Light Green,
# 4=Dark Green,5=Light Brown,6=Dark Brown)

# %%
type(data2018)
# Out:
# pandas.core.frame.DataFrame

# %%
data2018[["Measurements (mm)"]]
# Out:
# Unnamed: 0                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                             80,5.9
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  3.2,6.2,0.3,0.4,2.5,3.4,2,3.2,1.5
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                           20,26,17
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                              70,60
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                  70
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                72,87
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                  42,35,35,45,35,25
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            44,36,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                        6,5.2,4.2,3
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   30,30,50,40,30.5
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                              81,75
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...        4.1,3.5,3.6,4.2,5.5,3.3,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                      5,10
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      8
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                1,2
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         88,75
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                   105,88
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                     NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    1.5,3.4,1.3,2.3,2.2,2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              25,23,22,21
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     86,69
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                        NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                              35,18,32,53
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                        41,34,37,40,25,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5.2,4.5,5.1,3.5,3.5,3.2,5.5,5.1,5.3,4.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                            10,40.5,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                      NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    4,4.6,5.2,5.6,4.8,3.6,3.5,5.1,4.5,2.3
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                         15,6
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 115
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 56
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                          1.3,3.4,1,2.4,1.7,3.7,0.9
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                 70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,20,15,18,15,16,18,25,18,16,18,17,20,18,12,2...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  15.1,10.1,14.6,18.6,16,16,15.4,21.1,21.1,18.6,...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.6,3.3,4.3,3.2,3.5,6.2,5.1,3.6,5,3.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...             10,10,10,20,15,15,20,20,21,25,25,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                              3,2.1,3.1,1.9,3.7,2.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                               7,8.5,12
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                              2.4,3.1,2,1.5,2.7,1.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                              80,70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                               57,83
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                   75
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  28,23,20,20,20,20,15,21,18,8,18,15,17,13,16,20...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  29,16,21,7,9,18,2,25,27,26,8,9,5,16,19,13,20,3...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.7,4.5,4.9,2.8,7,3.2,4.8,4.5,4.5,2.9
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  3,3,4,5,5,10,10,10,10,15,10,10,25,25,25,30,32,...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                 73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              2,3.9,4.4,2.1,3.5,4.2,3.4,3.5,5.6,4.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                              Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                    NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                  3,2.1,3.1,1.9,3.7,2.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                    NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                    NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                      NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                26,20,38,27,30,28,41,40
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                     35
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  6.6,5.3,3.4,3,3.4,4.5,5.2,4.3,5.2,6.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                         35,20,30,45,27
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                    NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    3.6,4.4,2.6,4.3,4.2,4,3.4,3,3.6,2.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                           NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                        NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                    NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                               NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                          NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                    NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                         NaN
#
# Unnamed: 0                                                            Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                  NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...           2,3.12,4.4,2.1,3.5,4.2,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                  NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                75,64
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                    64
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                    NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,15,18,18,21,14,25,28,12,25,30,15
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                 20,25,20,30,15,13,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...    3.3,4.5,6,1.8,0.5,6.9,1,5.8,5.9,4
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...          22,19,15,27,22,4,3,15,15,16
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                   60
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  4.6,4.8,2.6,6,3.3,3.7,4.9,5,2.9,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                         NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                  NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                             NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                        NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                  NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                       NaN
#
# Unnamed: 0                                                                    Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                          6.1
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.7,3.8,2,4,2.13,3.5,1,4.04,2.1,3.9,4.7,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                          NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                           65
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                           NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                          37,68
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                            35,18,42,35,40,36
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                               30,40,30,41,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...            2.4,7.8,2,2.9,4.7,3.5,4.7,6,3,4.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                               25,30,32,35,43
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                           64
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6.5,5.2,3.4,5.7,3.2,4.3,6.6,6.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                 NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                              NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                          NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                     NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                          NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                               NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                       64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          3.2,3.01,4,2.04,1.09,1.07,2,1,1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                      NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                        80
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                         79
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                           58,30,34,28,37
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            60,28,20,25,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                    4.6,7,2.7,3.3,3,3.1,5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                           10,15,25,40,45
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                       73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  5.5,4.5,3.2,3.2,2.6,3.6,3.4,4.3,5.1,5.2
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                          NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                        Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                               70
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.1,1.4,2.2,3.4,1.2,3.2,2.3,3.3
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                               81
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                66
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                 30
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                   35,23,28,53,32
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...    25.3,14.1,46.6,31.6,26.3,26.1
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...      3,3.7,1,2.4,8.6,2,3.5,7,4,6
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   15,20,20,25,40
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                               80
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  6.7,3.8,5.1,3.5,3.9,6.5,2.7,3.4
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                     NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                  NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                              NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                    115
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                              NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                   NaN
#
# Unnamed: 0                                                                          Measurements (mm)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    5.6,4.4,5.6,2.5,3.2,2.4,3.5,2.1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...          23,27,20,18,22,30,35,16,26,32,23,18,18,21
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  14,30,10,21,10,19,18,22,30,26,17,15,10,10,20,1...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5,6.4,1.5,6.1,3.5,2.5,3.4,2.4,6,5.5,1.5,5.3,3....
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  10,10,15,20,20,30,25,25,35,30,35,35,35,40,35,4...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6,4.4,2.9,4.1,3.5,4.2,5.6,6.4,4.1,7.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN

# %%
'''
Revised way of analyizing the data to get means by water color
***********************************************************
'''
# Out:
# '\nRevised way of analyizing the data to get means by water color\n***********************************************************\n'

# %%
# Extract measurements and water color only
df = data2018[["Measurements (mm)","Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)"]]
row, col = df.shape # get the dimensions of the dataframe

'''
Could add mangle_dupe_cols = True in read_csv and dupe col names will be col1, col2
'''
wc = pd.Series(df.iloc[:,col-1]).astype(float) # Extract water colors and convert to float
y = pd.Series() # empty series

for r in range(row):
    x = pd.Series()
    for c in range(col-1):
        if type(df.iloc[r,c]) == str:
            h = pd.Series(df.iloc[r,c].split(",")).astype(float)
            for i in range(len(h)):
                if h.iloc[i] == 99999.0:  # some use 99999 as missing value
                    h = np.nan
            x = x.append(pd.Series(h))
        else:
            x = x.append(pd.Series(df.iloc[r,c]).astype(float))
    y = y.append(pd.Series(x.mean()))

WC = pd.DataFrame({'Water Color': wc.values, 'Mean': y})
WC.groupby('Water Color').mean()
# Out:
#                    Mean
# Water Color
# 1.0          102.666667
# 2.0           71.572090
# 3.0           24.619084
# 4.0           24.721346
# 5.0           14.254660
# 6.0           22.000000

# %%
wc
# Out:
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016                    3.0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016                            4.0
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016                    4.0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016                   6.0
# Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016                6.0
# 789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016    2.0
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                               2.0
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                4.0
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017                 5.0
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\r\nApril 20, 2017                3.0
# Sherman Creek 3\r\nSherman Creek South,\r\nApril 21, 2017                       3.0
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017                4.0
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                              2.0
# Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017                         5.0
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                     NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                  4.0
# No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017                    NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                    1.0
# Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017                  NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                   3.0
# Name: Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown), dtype: float64

# %%
# This stacks the measurements based on water color
v1 = np.array([])
v2 = np.array([])
v3 = np.array([])
v4 = np.array([])
v5 = np.array([])
v6 = np.array([])
for l in range(len(data2018["Measurements (mm)"].values)):
    # temp stores the observations for one expedition
    for t in range(10):
        if pd.notnull(data2018.iloc[l]['Measurements (mm)'].values[t]):
            w = np.array(data2018.iloc[l]["Measurements (mm)"].values[t].split(",")).astype(float)
            if data2018.iloc[l][wc] == '1':
                v1 = np.append(v1, w)
            elif data2018.iloc[l][wc] == '2':
                v2 = np.append(v2, w)
            elif data2018.iloc[l][wc] == '3':
                v3 = np.append(v3, w)
            elif data2018.iloc[l][wc] == '4':
                v4 = np.append(v4, w)
            elif data2018.iloc[l][wc] == '5':
                v5 = np.append(v5, w)
            else:
                v6 = np.append(v6, w)
        else:
            next
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-faba3e3935e7> in <module>()
#      11         if pd.notnull(data2018.iloc[l]['Measurements (mm)'].values[t]):
#      12             w = np.array(data2018.iloc[l]["Measurements (mm)"].values[t].split(",")).astype(float)
# ---> 13             if data2018.iloc[l][wc] == '1':
#      14                 v1 = np.append(v1, w)
#      15             elif data2018.iloc[l][wc] == '2':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     807             key = check_bool_indexer(self.index, key)
#     808
# --> 809         return self._get_with(key)
#     810
#     811     def _get_with(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     850                         return self.loc[key]
#     851
# --> 852                     return self.reindex(key)
#     853                 except Exception:
#     854                     # [slice(0, 5, None)] will break if you convert to ndarray,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    3320     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    3321     def reindex(self, index=None, **kwargs):
# -> 3322         return super(Series, self).reindex(index=index, **kwargs)
#    3323
#    3324     def drop(self, labels=None, axis=0, index=None, columns=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    3683         # perform the reindex on the axes
#    3684         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3685                                   fill_value, copy).__finalize__(self)
#    3686
#    3687     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3701             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    3702                                              fill_value=fill_value,
# -> 3703                                              copy=copy, allow_dups=False)
#    3704
#    3705         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    3804                                                 fill_value=fill_value,
#    3805                                                 allow_dups=allow_dups,
# -> 3806                                                 copy=copy)
#    3807
#    3808         if copy and new_data is self._data:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4412         # some axes don't allow reindexing with dups
#    4413         if not allow_dups:
# -> 4414             self.axes[axis]._can_reindex(indexer)
#    4415
#    4416         if axis >= self.ndim:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _can_reindex(self, indexer)
#    3557         # trying to reindex on an axis with duplicates
#    3558         if not self.is_unique and len(indexer):
# -> 3559             raise ValueError("cannot reindex from a duplicate axis")
#    3560
#    3561     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
# Combine the measurements with water color into a new data frame
measures = np.concatenate((v1, v2, v3, v4, v5, v6), axis=0)
measures = pd.DataFrame({'Measures': measures})

measures['WaterColor'] = np.zeros(len(measures['Measures']))

# %%
ind = np.array([len(v1), len(v2), len(v3), len(v4),len(v5),len(v6)])
ind

cumind = np.cumsum(ind)

# %%
for i in range(cumind[0]):
    measures.loc[i, 'WaterColor'] = 1
for j in range(5):
    for i in range(cumind[j],cumind[j+1]):
        measures.loc[i, 'WaterColor'] = j+2

# %%
#measures.head()
measures.groupby("WaterColor").mean()
# Out:
# Empty DataFrame
# Columns: [Measures]
# Index: []

# %%
# Some measurements are 99999 to indicate missing values! WHY???!!!
# So get rid of them; measures has all the data excluding those observations where 'Measures' is 99999
measures = measures[measures['Measures']!= 99999]

# %%
# Calculate the mean for each color
measures.groupby('WaterColor').mean()
# Out:
# Empty DataFrame
# Columns: [Measures]
# Index: []

# %%
measures.groupby('WaterColor').size()
# Out:
# Series([], dtype: int64)

# %%
measures['Measures'].plot.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-51204339b397> in <module>()
# ----> 1 measures['Measures'].plot.hist()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, bins, **kwds)
#    2831         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2832         """
# -> 2833         return self(kind='hist', bins=bins, **kwds)
#    2834
#    2835     @Appender(_kde_docstring % {
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
measures.groupby('WaterColor').mean().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d4d337561159> in <module>()
# ----> 1 measures.groupby('WaterColor').mean().plot.bar()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwds)
#    3088             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3089         """
# -> 3090         return self(kind='bar', x=x, y=y, **kwds)
#    3091
#    3092     def barh(self, x=None, y=None, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
measures.groupby('WaterColor').size().plot.bar()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-2b38993552e1> in <module>()
# ----> 1 measures.groupby('WaterColor').size().plot.bar()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, **kwds)
#    2781         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2782         """
# -> 2783         return self(kind='bar', **kwds)
#    2784
#    2785     def barh(self, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
# In this example, I made up a second variable to plot against my measurements data
# I added random normal fluctuations to the measurements data (i.e., random noise)
measures['Measures + Noise'] = measures['Measures'] + np.random.normal(0,4,627)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-9a460056d677> in <module>()
#       1 # In this example, I made up a second variable to plot against my measurements data
#       2 # I added random normal fluctuations to the measurements data (i.e., random noise)
# ----> 3 measures['Measures + Noise'] = measures['Measures'] + np.random.normal(0,4,627)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1064             rvalues = rvalues.values
#    1065
# -> 1066         result = safe_na_op(lvalues, rvalues)
#    1067         return construct_result(left, result,
#    1068                                 index=left.index, name=res_name, dtype=None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1028         try:
#    1029             with np.errstate(all='ignore'):
# -> 1030                 return na_op(lvalues, rvalues)
#    1031         except Exception:
#    1032             if is_object_dtype(lvalues):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1007
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#    1011             if isinstance(y, (np.ndarray, ABCSeries, pd.Index)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     203     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#     207
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     118
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#     122     return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      63         _store_test_result(False)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#      67
#
# ValueError: operands could not be broadcast together with shapes (0,) (627,)

# %%
measures.plot.scatter(y = 'Measures + Noise', x = 'Measures')

# %%
measures['Measures'].plot()

# %%
rn = np.array([[np.random.normal(0,1,100)],[np.random.normal(0.5,0.8,100)]])
plt.scatter(rn[0], rn[1])
plt.title('Zero Correlation')
plt.show()

# %%
w = np.random.normal(0,1,100)
rn = np.array([w,w+2*np.random.normal(0,0.1,100)])
plt.scatter(rn[0], rn[1])
plt.title('Positive Correlation')
plt.show()

# %%
w = np.random.normal(0,1,100)
rn = np.array([w, -w+3*np.random.normal(0.5,0.1,100)])
plt.scatter(rn[0], rn[1])
plt.title('Negative Correlation')
plt.show()
# Out:
# <div id='94dab3d2-13cb-4c80-9dac-087dedda7a64'></div>

# %%
measures['Measures'].plot.box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-c56ecc224334> in <module>()
# ----> 1 measures['Measures'].plot.box()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in box(self, **kwds)
#    2813         axes : :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#    2814         """
# -> 2815         return self(kind='box', **kwds)
#    2816
#    2817     def hist(self, bins=10, **kwds):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
measures.head()

# %%
np.corrcoef(measures['Measures'], measures['Measures + Noise'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-29f85c9946b1> in <module>()
# ----> 1 np.corrcoef(measures['Measures'], measures['Measures + Noise'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'

# %%
# The p-value near zero indicates the correlation is statistically significant
rho, pstat = scipy.stats.pearsonr(measures['Measures'], measures['Measures + Noise'])
print('rho = %.4f' % rho, 'p-val = %.4f' % pstat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-219f7665649b> in <module>()
#       1 # The p-value near zero indicates the correlation is statistically significant
# ----> 2 rho, pstat = scipy.stats.pearsonr(measures['Measures'], measures['Measures + Noise'])
#       3 print('rho = %.4f' % rho, 'p-val = %.4f' % pstat)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'

# %%
# We're testing the hypothesis that the two sample means are equal (statistically speaking)
tstat, pval = scipy.stats.ttest_ind(measures['Measures'], measures['Measures + Noise'])
print('t-stat = %.3f ' % tstat, 'p-value = %.3f' % pval)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-aa79663acebf> in <module>()
#       1 # We're testing the hypothesis that the two sample means are equal (statistically speaking)
# ----> 2 tstat, pval = scipy.stats.ttest_ind(measures['Measures'], measures['Measures + Noise'])
#       3 print('t-stat = %.3f ' % tstat, 'p-value = %.3f' % pval)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Measures + Noise'

# %%
# Test if the mean measurements in two water colors are the same --- they're not; low p-value
tstat, pval = scipy.stats.ttest_ind(v1, v5)
print('t-stat = %.3f ' % tstat, 'p-value = %.3f' % pval)
# Out:
# t-stat = nan  p-value = nan

# %%
# If you want to test if there is a difference in the means from multiple groups
# use Analysis of Variance(ANOVA) 
fstat, pval = stats.f_oneway(v1, v3, v4, v5, v6)
print('ANOVA Results', 'fstat = %.3f' % fstat, 'p-value = %.3f' % pval, '\n', sep='\t')

# The null nypothesis for ANOVA is all means are equal
# If your test suggests rejecting the null you need to do a Tukey HSD comparison
# to see which pairs of means are different
from statsmodels.stats.multicomp import pairwise_tukeyhsd
print(pairwise_tukeyhsd(measures['Measures'], measures['WaterColor']))
# Out:
# ANOVA Results	fstat = nan	p-value = nan
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:2917: RuntimeWarning: Mean of empty slice.
#   offset = alldata.mean()
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:2920: RuntimeWarning: invalid value encountered in double_scalars
#   sstot = _sum_of_squares(alldata) - (_square_of_sums(alldata) / float(bign))
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:2923: RuntimeWarning: invalid value encountered in double_scalars
#   ssbn += _square_of_sums(a - offset) / float(len(a))
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:2927: RuntimeWarning: invalid value encountered in double_scalars
#   ssbn -= (_square_of_sums(alldata) / float(bign))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a6c8fbad042f> in <module>()
#       8 # to see which pairs of means are different
#       9 from statsmodels.stats.multicomp import pairwise_tukeyhsd
# ---> 10 print(pairwise_tukeyhsd(measures['Measures'], measures['WaterColor']))
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\stats\multicomp.py in pairwise_tukeyhsd(endog, groups, alpha)
#      36     '''
#      37
# ---> 38     return MultiComparison(endog, groups).tukeyhsd(alpha=alpha)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\sandbox\stats\multicomp.py in __init__(self, data, groups, group_order)
#     822
#     823         if len(self.groupsunique) < 2:
# --> 824             raise ValueError('2 or more groups required for multiple comparisons')
#     825
#     826         self.datali = [self.data[self.groups == k] for k in self.groupsunique]
#
# ValueError: 2 or more groups required for multiple comparisons

# %%
# fixing the pH data issue for out of bounds data -- pH ranges from 0 to 14 
# note the original list is a list of str coming out of the BOP data
phs = pd.Series(['17.6', '8.2', '7.5'])
phsf = phs.astype(float)

# %%
phsf[phsf > 14.0] = np.nan
phsf
# Out:
# 0    NaN
# 1    8.2
# 2    7.5
# dtype: float64

# %%
phsf.mean()
# Out:
# 7.85
